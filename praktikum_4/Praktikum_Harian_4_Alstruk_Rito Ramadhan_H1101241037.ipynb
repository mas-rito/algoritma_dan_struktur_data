# %%
# Bubble sort in Python

#data = [5, 7, 3, 8, 1]
def bubbleSort(array):

  # loop to access each array element
  for i in range(len(array)):
  #for i in range(5)):
    #i=0
    # loop to compare array elements
    for j in range(0, len(array) - i - 1):
    #for j in range(0, 5 - 0 - 1):
    #for j in range(0, 4):
    #j=0
      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:
      #if array[0] > array[0 + 1]:
      #if array[0] > array[1]:
      #if 5 > 7:
      #data = [5, 7, 3, 8, 1]

      #j=1
      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:
      #if array[1] > array[1 + 1]:
      #if array[1] > array[2]:
      #if 7 > 3:
        arr[j], arr[j+1] = arr[j+1], arr[j]
        #arr[j], arr[j+1] = arr[1+1], arr[1]
        #arr[j], arr[j+1] = arr[2], arr[1]
        #arr[1], arr[2] = 3, 7
    #data = [5, 3, 7, 8, 1]

    #j=2
      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:
      #if array[2] > array[2 + 1]:
      #if array[2] > array[3]:
      #if 7 > 8:
      #data = [5, 3, 7, 8, 1]

      #j=3
      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:
      #if array[3] > array[3 + 1]:
      #if array[3] > array[4]:
      #if 8 > 1:
        arr[j], arr[j+1] = arr[j+1], arr[j]
        #arr[j], arr[j+1] = arr[3+1], arr[3]
        #arr[j], arr[j+1] = arr[4], arr[3]
        #arr[3], arr[4] = 1, 8
    #data = [5, 3, 7, 1, 8]

#i=1
    # loop to compare array elements
    for j in range(0, len(array) - i - 1):
    #for j in range(0, 5 - 1 - 1):
    #for j in range(0, 3):
    #j=0
      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:
      #if array[0] > array[0 + 1]:
      #if array[0] > array[1]:
      #if 5 > 3:
        arr[j], arr[j+1] = arr[j+1], arr[j]
        #arr[0], arr[0+1] = arr[0+1], arr[0]
        #arr[0], arr[1] = arr[1], arr[0]
        #arr[0], arr[1] = 3, 5
        #data = [3, 5, 7, 1, 8]

      #j=1
      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:
      #if array[1] > array[1 + 1]:
      #if array[1] > array[2]:
      #if 5 > 7:
         #data = [3, 5, 7, 1, 8]
    #j=2
      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:
      #if array[2] > array[2 + 1]:
      #if array[2] > array[3]:
      #if 7 > 1:
        arr[j], arr[j+1] = arr[j+1], arr[j]
        #arr[2], arr[2+1] = arr[2+1], arr[2]
        #arr[2], arr[3] = arr[3], arr[2]
        #arr[2], arr[3] = 1, 7
        #data = [3, 5, 1, 7, 8]

#i=2
    # loop to compare array elements
    for j in range(0, len(array) - i - 1):
    #for j in range(0, 5 - 2 - 1):
    #for j in range(0, 2):
    #j=0
      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:
      #if array[0] > array[0 + 1]:
      #if array[0] > array[1]:
      #if 3 > 5:
      
        #data = [3, 5, 1, 7, 8]

      #j=1
      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:
      #if array[1] > array[1 + 1]:
      #if array[1] > array[2]:
      #if 5 > 1:
        arr[j], arr[j+1] = arr[j+1], arr[j]
        #arr[1], arr[1+1] = arr[1+1], arr[1]
        #arr[1], arr[2] = arr[2], arr[1]
        #arr[1], arr[2] = 1, 5
        #data = [3, 1, 5, 7, 8]


#i=3
    # loop to compare array elements
    for j in range(0, len(array) - i - 1):
    #for j in range(0, 5 - 3 - 1):
    #for j in range(0, 1):
    #j=0
      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:
      #if array[0] > array[0 + 1]:
      #if array[0] > array[1]:
      #if 3 > 1:
        arr[j], arr[j+1] = arr[j+1], arr[j]
        #arr[0], arr[0+1] = arr[0+1], arr[1]
        #arr[0], arr[1] = arr[1], arr[1]
        #arr[0], arr[1] = 1, 3
       #data = [1, 3, 5, 7, 8]

data = [5, 7, 3, 8, 1]

bubbleSort(data)

print('Sorted Array in Ascending Order:')
print(data)

# %%
# Python program for implementation of Selection
# Sort
#arr = [5, 7, 3, 8, 1]
def selection_sort(arr):
    n = len(arr)
    #n = 5
    for i in range(n - 1):
    #for i in range(5 - 1):
    #for i in range(4):
    #i=0

        # Assume the current position holds
        # the minimum element
        min_idx = i
        #min_idx = 0

        # Iterate through the unsorted portion
        # to find the actual minimum
        for j in range(i + 1, n):
        #for j in range(i + 1, n):
        #for j in range(0 + 1, 5):
        #for j in range(1, 5):
        #j=1
            #arr = [5, 7, 3, 8, 1]
            if arr[j] < arr[min_idx]:
            #if arr[1] < arr[0]:
            #if 7 < 5:

        #j=2
            #arr = [5, 7, 3, 8, 1]
            if arr[j] < arr[min_idx]:
            #if arr[2] < arr[0]:
            #if 3 < 5:

                # Update min_idx if a smaller element is found
                min_idx = j
                #min_idx = 2
        #j=3
            #arr = [5, 7, 3, 8, 1]
            if arr[j] < arr[min_idx]:
            #if arr[3] < arr[2]:
            #if 8 < 3:
        #j=4
            #arr = [5, 7, 3, 8, 1]
            if arr[j] < arr[min_idx]:
            #if arr[4] < arr[2]:
            #if 1 < 3:
                min_idx = j
                #min_idx = 4

         arr[i], arr[min_idx] = arr[min_idx], arr[i]
        # arr[0], arr[4] = arr[4], arr[0]
        # arr[0], arr[4] = 1, 5
        #arr = [1, 7, 3, 8, 5]

    #i=1

        # Assume the current position holds
        # the minimum element
        min_idx = i
        #min_idx = 1

        # Iterate through the unsorted portion
        # to find the actual minimum
        for j in range(i + 1, n):
        #for j in range(i + 1, n):
        #for j in range(1 + 1, 5):
        #for j in range(2, 5):
        #j=2
            #arr = [1, 7, 3, 8, 5]
            if arr[j] < arr[min_idx]:
            #if arr[2] < arr[1]:
            #if 3 < 7:

                # Update min_idx if a smaller element is found
                min_idx = j
                #min_idx = 2
        #j=3
            #arr = [1, 7, 3, 8, 5]
            if arr[j] < arr[min_idx]:
            #if arr[3] < arr[2]:
            #if 8 < 3:

                # tetap
                min_idx = j
                #min_idx = 2
        #j=4
            #arr = [1, 7, 3, 8, 5]
            if arr[j] < arr[min_idx]:
            #if arr[4] < arr[2]:
            #if 5 < 3:
                 # tetap
                min_idx = j
                #min_idx = 2

         arr[i], arr[min_idx] = arr[min_idx], arr[i]
        #arr[1], arr[2] = arr[2], arr[1]
        #arr[1], arr[2] = 7, 3
        #arr = [1, 3, 7, 8, 5]

    #i=2

        # Assume the current position holds
        # the minimum element
        min_idx = i
        #min_idx = 2

        # Iterate through the unsorted portion
        # to find the actual minimum
        for j in range(i + 1, n):
        #for j in range(2 + 1, n):
        #for j in range(3, 5):
        #for j in range(3, 5):
        #j=3
            #arr = [1, 3, 7, 8, 5]
            if arr[j] < arr[min_idx]:
            #if arr[3] < arr[2]:
            #if 8 < 7:
             # tetap
                #min_idx = 2

        #j=4
            #arr = [1, 3, 7, 8, 5]
            if arr[j] < arr[min_idx]:
            #if arr[4] < arr[2]:
            #if 5 < 7:

                # Update min_idx if a smaller element is found
                min_idx = j
                #min_idx = 4

             arr[i], arr[min_idx] = arr[min_idx], arr[i]
            # arr[2], arr[4] = arr[4], arr[2]
            # arr[2], arr[4] = 7, 5

            #arr = [1, 3, 5, 8, 7]

    #i=3

        # Assume the current position holds
        # the minimum element
        min_idx = i
        #min_idx = 3

        # Iterate through the unsorted portion
        # to find the actual minimum
        for j in range(i + 1, n):
        #for j in range(3 + 1, n):
        #for j in range(4, 5):
        #j=4
            #arr = [1, 3, 5, 8, 7]
            if arr[j] < arr[min_idx]:
            #if arr[4] < arr[3]:
            #if 7 < 8:

                # tetap Update min_idx if a smaller element is found
                min_idx = j
                #min_idx = 3

        arr[i], arr[min_idx] = arr[min_idx], arr[i]
            # arr[3], arr[4] = arr[4], arr[3]
            # arr[3], arr[4] = 7, 8

            #arr = [1, 3, 5, 7, 8]




def print_array(arr):
    for val in arr:
        print(val, end=" ")
    print()

if __name__ == "__main__":
    arr = [5, 7, 3, 8, 1]

    print("Original array: ", end="")
    print_array(arr)

    selection_sort(arr)

    print("Sorted array: ", end="")
    print_array(arr)
